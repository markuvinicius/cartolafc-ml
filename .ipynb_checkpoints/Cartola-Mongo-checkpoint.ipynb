# %% [markdown]
# ## Análise cartola from mongodb

# %% [markdown]
# ### import nas bibliotecas do projeto

# %%
from pymongo import MongoClient
import pandas as pd
import numpy
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### configurações e definições

# %%
#URL do mongodb
_connection_url = 'mongodb://localhost:27017'
#nome do banco mongodb
_db_cartola='cartola-fc'
#nome da collection mongodb
_collection='mercado'
#id da rodada
_id_rodada=17

# %% [markdown]
# ## Legendas - Scouts

# %%
scouts_type = {
    'J' : ('Jogos',0.),
    'RB': ('Roubadas de Bola',+1.7),
    'FC': ('Falta Cometida',-0.5),
    'GC': ('Gol Contra',-6.),
    'CA': ('Cartão Amarelo',-2.),
    'CV': ('Cartão Vermelho',-5.),
    'SG': ('Jogos sem sofrer Gols',+5.),
    'DD': ('Defesa Difícil',+3.),
    'DP': ('Defesa de Penalti',+7.),
    'GS': ('Gol Sofrido',-2.),
    'FS': ('Falta Sofrida',+0.5),
    'PE': ('Passe Errado',-0.3),
    'A' : ('Assistencia',+5.),
    'FT': ('Finalizacao na trave',+3.5),
    'FD': ('Finalizacao Defendida',+1.),
    'FF': ('Finalizacao Fora',+0.7),
    'G' : ('Gol',+8.),
    'I' : ('Impedimento',-0.5),
    'PP': ('Penalti Perdido',-3.5)
}

# %% [markdown]
# ### Conexão com o mongo

# %%
mongo_client = MongoClient(_connection_url)
db = mongo_client[_db_cartola]

# %% [markdown]
# ### Função que retorna uma lista de atletas pelo número da rodada

# %%
def get_atletas_by_rodada(collection,rodada):
    document = db[_collection].find({'id_rodada':rodada})
    atletas = dict([i for i in document][0])['atletas']
    return atletas

# %% [markdown]
# ## Lendo dados da rodada com panda

# %%
data = pd.DataFrame(get_atletas_by_rodada(_collection,18))
data
# Out:
#                apelido        clube     id  pontos             posicao  \
# 0           Ferdinando         Avaí  53731    0.00      [4, Meia, mei]
# 1               Gilson     Botafogo  52674    0.00   [2, Lateral, lat]
# 2     Anderson Martins        Vasco  52618    0.00  [3, Zagueiro, zag]
# 3          Lucas Rocha        Vasco  94119    0.00  [3, Zagueiro, zag]
# 4              Cuéllar     Flamengo  71709    3.90      [4, Meia, mei]
# 5               Victor  Atlético-MG  52950    9.00   [1, Goleiro, gol]
# 6              Ribamar  Atlético-PR  94068   11.40  [5, Atacante, ata]
# 7    Matheus Fernandes     Botafogo  94067    9.30      [4, Meia, mei]
# 8                Devid         Avaí  94105    0.00  [5, Atacante, ata]
# 9              Matheus         Avaí  94102    0.00   [1, Goleiro, gol]
# 10         Diego Gomes       Santos  94045    0.00      [4, Meia, mei]
# 11         John Victor       Santos  94044    0.00   [1, Goleiro, gol]
# 12           Thallyson        Sport  94144    0.00      [4, Meia, mei]
# 13             Perotti  Chapecoense  94286    0.00  [5, Atacante, ata]
# 14        Felipe Vizeu     Flamengo  94138    0.00  [5, Atacante, ata]
# 15                Lima  Chapecoense  94288    0.00      [4, Meia, mei]
# 16      Lucas Ferreira        Sport  94147    0.00   [1, Goleiro, gol]
# 17           Guilherme     Botafogo  94207    8.30  [5, Atacante, ata]
# 18             Juninho        Sport  94445    0.90  [5, Atacante, ata]
# 19       Raphael Veiga    Palmeiras  94509    6.90      [4, Meia, mei]
# 20            Lourency  Chapecoense  94249    1.50  [5, Atacante, ata]
# 21               Elias  Atlético-MG  54395    3.00      [4, Meia, mei]
# 22               Pedro   Fluminense  94583    0.00  [5, Atacante, ata]
# 23       Mateus Norton   Fluminense  94336    0.00      [4, Meia, mei]
# 24                 Léo         Avaí  94885    0.00   [2, Lateral, lat]
# 25          Léo Duarte     Flamengo  94214    0.00  [3, Zagueiro, zag]
# 26       Lucas Paquetá     Flamengo  94930    0.00      [4, Meia, mei]
# 27               Lucão     Cruzeiro  94962    0.00   [1, Goleiro, gol]
# 28     Lucas Fernandes    São Paulo  94931    0.00      [4, Meia, mei]
# 29       Manga Escobar        Vasco  71704    0.10  [5, Atacante, ata]
# ..                 ...          ...    ...     ...                 ...
# 807        Felipe Melo    Palmeiras  38545    0.00      [4, Meia, mei]
# 808             Maicon         Avaí  38748    0.00   [2, Lateral, lat]
# 809            Douglas       Grêmio  38738    0.00      [4, Meia, mei]
# 810              Diego     Flamengo  38909   -2.20      [4, Meia, mei]
# 811             Renato       Santos  38908    0.00      [4, Meia, mei]
# 812              Jonas     Botafogo  39152    0.00   [2, Lateral, lat]
# 813             Renato   Fluminense  39572    0.00   [2, Lateral, lat]
# 814     Rafael Marques     Cruzeiro  38957    0.00  [5, Atacante, ata]
# 815   Ricardo Oliveira       Santos  38910   -1.90  [5, Atacante, ata]
# 816      Dudu Cearense     Botafogo  38928    0.00      [4, Meia, mei]
# 817               Nenê        Vasco  38913    0.00      [4, Meia, mei]
# 818     Vagner Mancini      Vitória  39850    5.25   [6, Técnico, tec]
# 819        Levir Culpi       Santos  40025    3.27   [6, Técnico, tec]
# 820         Abel Braga   Fluminense  40006    0.00   [6, Técnico, tec]
# 821              Denis    São Paulo  51175    0.00   [1, Goleiro, gol]
# 822      Emerson Silva     Botafogo  51299    0.00  [3, Zagueiro, zag]
# 823             Kleber     Coritiba  40179    0.00  [5, Atacante, ata]
# 824     Roger Carvalho  Atlético-GO  51415    2.10  [3, Zagueiro, zag]
# 825     Dorival Júnior    São Paulo  40990    4.25   [6, Técnico, tec]
# 826   Leandro Donizete       Santos  51318    0.50      [4, Meia, mei]
# 827             Walter  Corinthians  51413    0.00   [1, Goleiro, gol]
# 828      Bruno Rodrigo       Grêmio  51705    0.00  [3, Zagueiro, zag]
# 829        Renato Cajá  Ponte Preta  51319    0.00      [4, Meia, mei]
# 830             Aranha  Ponte Preta  37984    0.00   [1, Goleiro, gol]
# 831     Thiago Carleto     Coritiba  51700    0.00   [2, Lateral, lat]
# 832               Kanu      Vitória  51792    5.00  [3, Zagueiro, zag]
# 833              Réver     Flamengo  52253   10.20  [3, Zagueiro, zag]
# 834     Leandro Salino      Vitória  51905    0.00   [2, Lateral, lat]
# 835    Éverton Ribeiro     Flamengo  51772    1.30      [4, Meia, mei]
# 836           Anderson     Coritiba  38852    0.00      [4, Meia, mei]
#
#                                                  scout           status
# 0                                                   {}        [6, Nulo]
# 1    {'A': 1, 'CA': 3, 'FC': 7, 'FF': 1, 'FS': 19, ...        [6, Nulo]
# 2                                                   {}        [6, Nulo]
# 3                                                   {}        [6, Nulo]
# 4    {'CA': 2, 'FC': 12, 'FD': 2, 'FS': 4, 'PE': 18...        [6, Nulo]
# 5    {'CA': 3, 'DD': 24, 'DP': 3, 'FC': 1, 'FS': 2,...    [7, Provável]
# 6    {'FC': 4, 'FF': 3, 'FS': 5, 'G': 1, 'I': 2, 'P...    [7, Provável]
# 7    {'CA': 1, 'FC': 17, 'FF': 5, 'FS': 9, 'PE': 18...      [2, Dúvida]
# 8                                                   {}        [6, Nulo]
# 9                                                   {}        [6, Nulo]
# 10                                                  {}        [6, Nulo]
# 11                                                  {}        [6, Nulo]
# 12   {'CA': 2, 'FC': 10, 'FS': 7, 'I': 1, 'PE': 12,...        [6, Nulo]
# 13       {'FC': 2, 'FF': 1, 'FS': 2, 'PE': 2, 'RB': 1}        [6, Nulo]
# 14       {'FC': 4, 'FF': 2, 'FS': 2, 'PE': 4, 'RB': 1}        [6, Nulo]
# 15                                                  {}        [6, Nulo]
# 16                                                  {}        [6, Nulo]
# 17   {'A': 1, 'FC': 9, 'FD': 4, 'FF': 7, 'FS': 23, ...        [6, Nulo]
# 18   {'CA': 1, 'FC': 5, 'FD': 1, 'FF': 2, 'FS': 4, ...        [6, Nulo]
# 19   {'A': 1, 'CA': 2, 'FC': 6, 'FD': 1, 'FF': 4, '...        [6, Nulo]
# 20   {'A': 1, 'CA': 2, 'FC': 7, 'FD': 2, 'FF': 3, '...        [6, Nulo]
# 21   {'CA': 1, 'FC': 18, 'FD': 5, 'FF': 1, 'FS': 12...      [2, Dúvida]
# 22   {'CA': 1, 'FC': 7, 'FD': 2, 'FF': 2, 'FS': 8, ...        [6, Nulo]
# 23   {'CA': 3, 'FC': 3, 'FF': 1, 'FS': 2, 'PE': 7, ...        [6, Nulo]
# 24                                                  {}        [6, Nulo]
# 25                {'FC': 2, 'FS': 1, 'PE': 1, 'SG': 1}        [6, Nulo]
# 26                {'FC': 1, 'FS': 1, 'PE': 1, 'RB': 1}        [6, Nulo]
# 27                                                  {}        [6, Nulo]
# 28   {'CA': 1, 'FC': 3, 'FD': 2, 'FF': 3, 'FS': 4, ...  [5, Contundido]
# 29   {'A': 1, 'FC': 3, 'FD': 2, 'FF': 3, 'FS': 7, '...        [6, Nulo]
# ..                                                 ...              ...
# 807  {'CA': 2, 'FC': 10, 'FD': 1, 'FF': 2, 'FS': 9,...        [6, Nulo]
# 808      {'FC': 1, 'FF': 1, 'FS': 2, 'GC': 1, 'PE': 4}        [6, Nulo]
# 809                                                 {}  [5, Contundido]
# 810  {'A': 2, 'CA': 1, 'FC': 16, 'FD': 5, 'FF': 11,...    [7, Provável]
# 811   {'FC': 6, 'FF': 1, 'FS': 14, 'PE': 23, 'RB': 11}    [7, Provável]
# 812                                                 {}  [5, Contundido]
# 813  {'CA': 2, 'FC': 10, 'FD': 1, 'FF': 6, 'FS': 7,...        [6, Nulo]
# 814  {'FC': 3, 'FD': 2, 'FF': 5, 'FS': 9, 'G': 1, '...        [6, Nulo]
# 815  {'CA': 1, 'FC': 9, 'FD': 2, 'FF': 6, 'FS': 5, ...    [7, Provável]
# 816  {'CA': 2, 'FC': 8, 'FD': 1, 'FS': 2, 'PE': 9, ...        [6, Nulo]
# 817  {'A': 3, 'CA': 3, 'FC': 13, 'FD': 5, 'FF': 7, ...        [6, Nulo]
# 818                                                 {}    [7, Provável]
# 819                                                 {}    [7, Provável]
# 820                                                 {}    [7, Provável]
# 821                                                 {}        [6, Nulo]
# 822      {'FC': 2, 'FF': 1, 'FS': 5, 'PE': 8, 'RB': 6}        [6, Nulo]
# 823  {'A': 1, 'CA': 1, 'CV': 1, 'FC': 28, 'FD': 10,...    [3, Suspenso]
# 824  {'A': 1, 'FC': 26, 'FF': 10, 'FS': 31, 'FT': 1...    [7, Provável]
# 825                                                 {}    [7, Provável]
# 826  {'CA': 2, 'FC': 9, 'FF': 1, 'FS': 7, 'PE': 10,...        [6, Nulo]
# 827                                                 {}        [6, Nulo]
# 828                                          {'PE': 1}        [6, Nulo]
# 829  {'A': 2, 'CA': 1, 'CV': 1, 'FC': 10, 'FD': 1, ...        [6, Nulo]
# 830  {'CA': 1, 'DD': 30, 'FS': 3, 'GS': 21, 'PE': 6...    [7, Provável]
# 831  {'FC': 3, 'FD': 4, 'FS': 4, 'PE': 12, 'RB': 4,...        [6, Nulo]
# 832  {'A': 1, 'CA': 3, 'FC': 11, 'FD': 1, 'FF': 7, ...    [7, Provável]
# 833  {'CA': 1, 'FC': 6, 'FD': 3, 'FF': 2, 'FS': 12,...    [7, Provável]
# 834  {'CA': 1, 'FC': 15, 'FF': 2, 'FS': 16, 'PE': 2...        [6, Nulo]
# 835  {'A': 4, 'CA': 1, 'FC': 7, 'FD': 3, 'FF': 2, '...    [7, Provável]
# 836  {'CA': 2, 'FC': 7, 'FD': 3, 'FS': 7, 'PE': 17,...  [5, Contundido]
#
# [837 rows x 7 columns]

# %%
data['scout'].iloc[824]
# Out:
# {'A': 1, 'FC': 26, 'FF': 10, 'FS': 31, 'FT': 1, 'PE': 38, 'RB': 22, 'SG': 1}
