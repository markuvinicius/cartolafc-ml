# %% [markdown]
# # Análise de dados do cartolafc com Machine Learning
#
# ### Autor: Marku Vinícius
# ### Data: 10/06/2017

# %%
# import de bibliotecas utilizadas no projeto

import graphlab
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

rodada_atual = 6

# %% [raw]
# ## Import dos dados obtidos do cartola para o graphlab

# %%
data = graphlab.SFrame('cartola_data.csv')
# Out:
# Finished parsing file /Users/Marku/Documents/data_center/WorkSpace/cartola-ml/cartola_data.csv
# Parsing completed. Parsed 100 lines in 0.028991 secs.
# Finished parsing file /Users/Marku/Documents/data_center/WorkSpace/cartola-ml/cartola_data.csv
# Parsing completed. Parsed 806 lines in 0.015385 secs.

# %% [markdown]
# ## Limpa os atletas que não possuem nenhum scout ou não pontuaram nas últimas rodadas

# %%
feat_scouts = ["FD","G","CA","FC","FS","DD","GS","PP",
               "SG","CV","FT","A","PE","RB","DP","I","FF",
               "R1","R2","R3","R4","R5","R6",
               "R7","R8","R9","R10","R11","R12"]

data = data.dropna(columns=feat_scouts,how="any")

data = data[(data['status']=='Provável') & (data['ultima_pontuacao']!=0)]

# %% [markdown]
# ## Análise dos times

# %%
# agrupa os times
clubes = data.groupby( ['clube'], 
                { 'media'   : graphlab.aggregate.MEAN('ultima_pontuacao') }
            ).topk('media',5)

# %%
#graphlab.canvas.set_target('browser')
graphlab.canvas.set_target('ipynb')

# %%
clubes.topk('media',7).show(view='Bar Chart')

# %%
# %matplotlib inline

f = plt.Figure(figsize=(200,200))
#plt.bar(clubes['clube'] , clubes['media'] ,width=0.8 )
#clubes['clube','media'].plot()
fontsize2use = 10
plt.xticks(fontsize=fontsize2use)  
plt.yticks(fontsize=fontsize2use)    
fontprop = fm.FontProperties(size=fontsize2use)

plt.bar( 
            range( len( clubes ) ) ,
            clubes['media'] ,
            width=2 
)

plt.xticks(range(10),clubes['clube'])

plt.bar?

# %%
data['ultima_pontuacao'].sort(ascending=False).show(view='Categorical')
#graphlab.SFrame.sort?

# %% [markdown]
# ## Separação dos datasets e criação do modelo
#
# ### features: scouts do cartola

# %%
train_data , test_data = data.random_split(.8,seed=0)

# %%
model = graphlab.linear_regression.create(
                                                dataset=train_data,
                                                target='ultima_pontuacao',
                                                features=feat_scouts,
                                                validation_set=test_data
                                            )

min_scouts = ["FD","G","CA","FC","FS","DD","GS","PP",
               "SG","CV","FT","A","PE","RB","DP","I","FF"]

min_model = graphlab.linear_regression.create(
                                                dataset=train_data,
                                                target='ultima_pontuacao',
                                                features=min_scouts,
                                                validation_set=test_data
                                            )
# Out:
# WARNING: Detected extremely low variance for feature(s) 'CV', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12' because all entries are nearly the same.
# Proceeding with model training using all features. If the model does not provide results of adequate quality, exclude the above mentioned feature(s) from the input dataset.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 147
# Number of features          : 29
# Number of unpacked features : 29
# Number of coefficients    : 23
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.001102     | 0.002862           | 0.001618             | 0.000763      | 0.000697        |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>
# WARNING: Detected extremely low variance for feature(s) 'CV' because all entries are nearly the same.
# Proceeding with model training using all features. If the model does not provide results of adequate quality, exclude the above mentioned feature(s) from the input dataset.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 147
# Number of features          : 17
# Number of unpacked features : 17
# Number of coefficients    : 18
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.001928     | 15.779167          | 12.203213            | 3.737539      | 4.310120        |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
plt.Figure()
x=[1,2]
y=[model.evaluate(test_data)['rmse'] , min_model.evaluate(test_data)['rmse']]

plt.plot( x , y ,marker='o',c='r' )
plt.xlabel('Modelos Preditivos Utilizados')
plt.ylabel('Erro RMSE')
plt.xticks(x)
plt.yticks(y)
plt.title('RMSE dos modelos')

# %%
data['pd1'] = model.predict(data)
data['pd2'] = min_model.predict(data)
data['erro1'] = data['ultima_pontuacao'] - data['pd1']
data['erro2'] = data['ultima_pontuacao'] - data['pd2']

# %%
# %matplotlib inline

def plot_athlete_performance(apelido):
    atleta1=data[data['apelido']==apelido]

    if ( len(atleta1) == 1 ):
        plt.Figure(figsize=(20,10))

        x=[]
        y=[]

        for i in range(1,rodada_atual):
            x.append(i)
            y.append(atleta1['R{}'.format(i)])

        plt.plot( x , y , marker='o' , c='r')
        plt.plot( rodada_atual , atleta1['pd1'],marker='x',c='b')
        plt.plot( rodada_atual , atleta1['pd2'],marker='v',c='g')
        plt.xlabel('turno')
        plt.ylabel('pontuacao')
        plt.title('Performance {} - {}'.format(atleta1['apelido'],atleta1['clube']))
        plt.legend(('histórico','model1','model2'))
    else:
        print('Atleta não encontrado')

# %%
plot_athlete_performance('Marquinhos Gabriel')

# %% [markdown]
# ## Função para plotar os atletas por posição

# %%
# %matplotlib inline

def plot_position_graph(sframe):
    fig,axes = plt.subplots(2,5,sharey=True,figsize=(15,10))
    #fig = plt.figure(figsize=(8, 6)) 
    c='r'
    marker='o'

    for n in range(len(axes.flat)):
        ax = axes.flat[n]
        x=[]
        y=[]

        for rodada in range(1,rodada_atual):
            x.append( rodada )
            y.append( sframe[n]['R{}'.format(rodada)] )

        #print( str(goleiros[n]['apelido']).encode("utf-8") )        
        ax.plot( x , y , marker=marker , c=c )

        #plota a previsão no modelo completo - em azul
        ax.plot( rodada_atual , sframe[n]['pd1'] , marker='o' , c='b' )
        #plota a previsão no modelo resumido - em verde
        ax.plot( rodada_atual , sframe[n]['pd2'] , marker='o' , c='g' )

        x.append(rodada_atual)    

        ax.set_xlabel('turno')
        ax.set_ylabel('pontuacao')
        ax.set_title( sframe[n]['apelido'] + '-' + sframe[n]['clube'] )
        ax.set_xticks(x)

        ax.legend(('histórico', 'model1', 'model2'))

# %% [markdown]
# # Análise dos goleiros
#
# ## Análise gráfica da performance versus pontuações previstas para cada goleiro

# %%
goleiros = data[(data['posicao.1']=='Goleiro')]
goleiros = goleiros['apelido','clube','ultima_pontuacao','pd1','pd2','erro1','erro2','R1','R2',
                        'R3','R4','R5','R6','R7','R8','R9'].topk('pd1',10)

# %%
plot_position_graph(goleiros)

# %% [markdown]
# # Análise dos Zagueiros
#
# ## Análise gráfica da performance versus pontuações previstas para cada goleiro

# %%
zagueiros = data[(data['posicao.1']=='Zagueiro')]
zagueiros = zagueiros['apelido','clube','ultima_pontuacao','pd1','pd2','erro1','erro2','R1','R2',
                        'R3','R4','R5','R6','R7','R8','R9'].topk('pd1',10)

# %%
plot_position_graph(zagueiros)

# %% [markdown]
# # Análise dos Meias
#
# ## Análise gráfica da performance versus pontuações previstas para cada atleta

# %%
meias = data[(data['posicao.1']=='Meia') ]
meias = meias['apelido','clube','ultima_pontuacao','pd1','pd2','erro1','erro2','R1','R2',
                        'R3','R4','R5','R6','R7','R8','R9'].topk('pd1',10)

# %%
plot_position_graph(meias)

# %% [markdown]
# # Análise dos Meias
#
# ## Análise gráfica da performance versus pontuações previstas para cada atleta

# %%
atacantes = data[(data['posicao.1']=='Atacante') ]
atacantes = atacantes['apelido','clube','ultima_pontuacao','pd1','pd2','erro1','erro2','R1','R2',
                        'R3','R4','R5','R6','R7','R8','R9'].topk('pd1',10)

# %%
plot_position_graph(atacantes)

# %% [markdown]
# # Análise dos Técnicos
#
# ## Análise gráfica da performance versus pontuações previstas para cada atleta

# %%
tecnicos = data[(data['posicao.1']=='Técnico') ]
tecnicos = tecnicos['apelido','clube','ultima_pontuacao','pd1','pd2','erro1','erro2','R1','R2',
                        'R3','R4','R5','R6','R7','R8','R9'].topk('pd1',10)

# %%
plot_position_graph(tecnicos)
